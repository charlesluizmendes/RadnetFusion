# %%
# %run 5.kalman.ipynb
# Out:
# Dataset salvo em ../datasets/edges.csv
#      src   dest       rssi       etx      delay  busy_fraction  label
# 0    694  97940 -45.375348  2.816423  23.884050       0.334729      1
# 1  66680  27923 -40.480811  3.027440  10.715974       0.272414      1
# 2  87828  26270 -69.363116  9.402757  79.306127       0.665820      0
# 3  66371  88162 -57.697086  1.917398  24.426673       0.041456      1
# 4  28477   4495 -57.272842  7.171275   9.604435       0.745936      0
#
# Distribuição dos labels:
# label
# 1    100000
# 0    100000
# Name: count, dtype: int64
#
#
# Epoch 0, Loss 0.5195, Train Acc 0.9521, Test Acc 0.9639
# Epoch 10, Loss 0.1860, Train Acc 0.9758, Test Acc 0.9765
# Epoch 20, Loss 0.0740, Train Acc 0.9804, Test Acc 0.9813
# Epoch 30, Loss 0.0491, Train Acc 0.9837, Test Acc 0.9844
# Epoch 40, Loss 0.0402, Train Acc 0.9861, Test Acc 0.9867
#
# Acurácia final no conjunto de teste: 0.9882
#
# Matriz de Confusão:
# [[29573   427]
#  [  281 29719]]
#
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#         Ruim       0.99      0.99      0.99     30000
#          Bom       0.99      0.99      0.99     30000
#
#     accuracy                           0.99     60000
#    macro avg       0.99      0.99      0.99     60000
# weighted avg       0.99      0.99      0.99     60000
#
# Modelo salvo em ../models/mlp.pth
# Modelo salvo em ../models/scaler.pkl
# Aresta [-55, 2, 17, 0.3] -> Classe 1 (Bom) (confiança 1.00)
# Aresta [-85, 3.8, 30, 0.1] -> Classe 1 (Bom) (confiança 0.54)
# Aresta [-35, 1.2, 5, 0.05] -> Classe 1 (Bom) (confiança 1.00)
# Aresta [-88, 9.5, 95, 0.9] -> Classe 0 (Ruim) (confiança 1.00)
# Aresta [-40, 8.2, 85, 0.8] -> Classe 0 (Ruim) (confiança 1.00)
# Aresta [-87, 1.5, 8, 0.15] -> Classe 1 (Bom) (confiança 0.98)
# Aresta [-62, 2.8, 32, 0.28] -> Classe 1 (Bom) (confiança 0.95)
# Aresta [-58, 3.2, 28, 0.32] -> Classe 1 (Bom) (confiança 0.96)
# Aresta [-52, 2.1, 20, 0.25] -> Classe 1 (Bom) (confiança 1.00)
# Aresta [-48, 2.5, 25, 0.22] -> Classe 1 (Bom) (confiança 1.00)
# Aresta [-50, 1.8, 22, 0.28] -> Classe 1 (Bom) (confiança 1.00)
# Aresta [-75, 5.2, 65, 0.6] -> Classe 0 (Ruim) (confiança 1.00)
# Aresta [-78, 4.8, 70, 0.65] -> Classe 0 (Ruim) (confiança 1.00)
# Aresta [-72, 5.5, 60, 0.58] -> Classe 0 (Ruim) (confiança 1.00)
# Aresta [-45, 4.5, 15, 0.7] -> Classe 1 (Bom) (confiança 0.57)
# Aresta [-70, 1.9, 45, 0.2] -> Classe 1 (Bom) (confiança 0.89)
# Aresta [-60, 2.9, 30, 0.3] -> Classe 1 (Bom) (confiança 0.96)
# Aresta [-65, 2.2, 18, 0.25] -> Classe 1 (Bom) (confiança 0.99)
# Aresta [-50, 3.5, 35, 0.35] -> Classe 1 (Bom) (confiança 0.94)
# Aresta [-32, 1.1, 3, 0.02] -> Classe 1 (Bom) (confiança 1.00)
# Aresta [-90, 9.8, 98, 0.95] -> Classe 0 (Ruim) (confiança 1.00)
# Aresta [-38, 1.3, 7, 0.08] -> Classe 1 (Bom) (confiança 1.00)
# Aresta [-86, 8.5, 88, 0.85] -> Classe 0 (Ruim) (confiança 1.00)
# Aresta [-42, 1.6, 12, 0.12] -> Classe 1 (Bom) (confiança 1.00)
# Aresta [-33, 7.2, 75, 0.8] -> Classe 0 (Ruim) (confiança 1.00)
# Aresta [-82, 1.2, 8, 0.1] -> Classe 1 (Bom) (confiança 0.99)
# Aresta [-75, 8.1, 5, 0.85] -> Classe 0 (Ruim) (confiança 1.00)
# Aresta [-68, 6.5, 85, 0.05] -> Classe 0 (Ruim) (confiança 0.99)
# Aresta [-89, 2.1, 18, 0.15] -> Classe 1 (Bom) (confiança 0.87)
# Aresta [-45, 9.2, 22, 0.2] -> Classe 0 (Ruim) (confiança 0.80)
# Aresta [-52, 2.3, 95, 0.25] -> Classe 0 (Ruim) (confiança 0.79)
# Aresta [-48, 2.0, 20, 0.88] -> Classe 1 (Bom) (confiança 0.69)
# Aresta [-59, 3.0, 29, 0.29] -> Classe 1 (Bom) (confiança 0.97)
# Aresta [-61, 2.9, 31, 0.31] -> Classe 1 (Bom) (confiança 0.94)
# Aresta [-60.5, 3.05, 30.5, 0.305] -> Classe 1 (Bom) (confiança 0.94)
# Aresta [-59.5, 2.95, 29.5, 0.295] -> Classe 1 (Bom) (confiança 0.96)
# Aresta [-67, 4.2, 45, 0.5] -> Classe 0 (Ruim) (confiança 0.97)
# Aresta [-64, 3.8, 42, 0.48] -> Classe 0 (Ruim) (confiança 0.89)
# Aresta [-69, 4.5, 48, 0.52] -> Classe 0 (Ruim) (confiança 0.99)
# Aresta [-66, 4.0, 40, 0.45] -> Classe 0 (Ruim) (confiança 0.89)
# Aresta [-54, 1.9, 16, 0.28] -> Classe 1 (Bom) (confiança 1.00)
# Aresta [-56, 2.2, 19, 0.26] -> Classe 1 (Bom) (confiança 1.00)
# Aresta [-51, 1.7, 21, 0.24] -> Classe 1 (Bom) (confiança 1.00)
# Aresta [-49, 2.4, 18, 0.27] -> Classe 1 (Bom) (confiança 1.00)
# Aresta [-53, 2.0, 23, 0.29] -> Classe 1 (Bom) (confiança 1.00)
# Aresta [-76, 5.8, 67, 0.63] -> Classe 0 (Ruim) (confiança 1.00)
# Aresta [-74, 5.1, 62, 0.59] -> Classe 0 (Ruim) (confiança 1.00)
# Aresta [-77, 6.2, 72, 0.68] -> Classe 0 (Ruim) (confiança 1.00)
# Aresta [-73, 5.5, 58, 0.56] -> Classe 0 (Ruim) (confiança 1.00)
# Aresta [-79, 5.9, 75, 0.71] -> Classe 0 (Ruim) (confiança 1.00)
# Aresta [-55, 1.8, 35, 0.6] -> Classe 1 (Bom) (confiança 0.83)
# Aresta [-45, 4.2, 25, 0.7] -> Classe 0 (Ruim) (confiança 0.58)
# Aresta [-65, 2.5, 18, 0.55] -> Classe 1 (Bom) (confiança 0.80)
# Aresta [-58, 3.8, 28, 0.8] -> Classe 0 (Ruim) (confiança 0.96)
# Aresta [-41, 5.0, 50, 0.5] -> Classe 0 (Ruim) (confiança 0.83)
# Aresta [-80, 2.0, 20, 0.2] -> Classe 1 (Bom) (confiança 0.94)
# Aresta [-60, 6.0, 60, 0.6] -> Classe 0 (Ruim) (confiança 1.00)
# Aresta [-50, 2.5, 25, 0.25] -> Classe 1 (Bom) (confiança 1.00)
# Aresta [-57, 2.8, 28, 0.28] -> Classe 1 (Bom) (confiança 0.98)
# Aresta [-63, 3.2, 32, 0.32] -> Classe 1 (Bom) (confiança 0.88)
# Aresta [-58, 2.9, 31, 0.29] -> Classe 1 (Bom) (confiança 0.97)
# Aresta [-62, 3.1, 29, 0.31] -> Classe 1 (Bom) (confiança 0.93)
# Aresta [-30, 1.0, 1, 0.01] -> Classe 1 (Bom) (confiança 1.00)
# Aresta [-90, 10.0, 100, 1.0] -> Classe 0 (Ruim) (confiança 1.00)
# Aresta [-31, 1.5, 10, 0.05] -> Classe 1 (Bom) (confiança 1.00)
# Aresta [-89, 9.0, 90, 0.9] -> Classe 0 (Ruim) (confiança 1.00)
# Aresta [-44, 7.5, 12, 0.15] -> Classe 1 (Bom) (confiança 0.93)
# Aresta [-83, 1.8, 78, 0.75] -> Classe 0 (Ruim) (confiança 1.00)
# Aresta [-38, 6.8, 8, 0.82] -> Classe 0 (Ruim) (confiança 0.90)
# Aresta [-71, 1.4, 55, 0.18] -> Classe 1 (Bom) (confiança 0.84)
#
# Saída após fusão espacial (MLP + APMR_edge + MFSR_edge + IGD_global):
# Aresta [-55, 2, 17, 0.3] | MLP=1.00, APMR_edge=0.65, MFSR_edge=0.85, IGD=0.62 -> Score=0.85 => Classe 1 (Bom)
# Aresta [-85, 3.8, 30, 0.1] | MLP=0.54, APMR_edge=0.68, MFSR_edge=0.85, IGD=0.62 -> Score=0.63 => Classe 1 (Bom)
# Aresta [-35, 1.2, 5, 0.05] | MLP=1.00, APMR_edge=0.70, MFSR_edge=0.85, IGD=0.62 -> Score=0.86 => Classe 1 (Bom)
# Aresta [-88, 9.5, 95, 0.9] | MLP=0.00, APMR_edge=0.73, MFSR_edge=0.84, IGD=0.62 -> Score=0.37 => Classe 0 (Ruim)
# Aresta [-40, 8.2, 85, 0.8] | MLP=0.00, APMR_edge=0.75, MFSR_edge=0.84, IGD=0.62 -> Score=0.37 => Classe 0 (Ruim)
# Aresta [-87, 1.5, 8, 0.15] | MLP=0.98, APMR_edge=0.78, MFSR_edge=0.83, IGD=0.62 -> Score=0.86 => Classe 1 (Bom)
# Aresta [-62, 2.8, 32, 0.28] | MLP=0.95, APMR_edge=0.80, MFSR_edge=0.83, IGD=0.62 -> Score=0.85 => Classe 1 (Bom)
# Aresta [-58, 3.2, 28, 0.32] | MLP=0.96, APMR_edge=0.81, MFSR_edge=0.82, IGD=0.62 -> Score=0.86 => Classe 1 (Bom)
# Aresta [-52, 2.1, 20, 0.25] | MLP=1.00, APMR_edge=0.83, MFSR_edge=0.81, IGD=0.62 -> Score=0.88 => Classe 1 (Bom)
# Aresta [-48, 2.5, 25, 0.22] | MLP=1.00, APMR_edge=0.84, MFSR_edge=0.80, IGD=0.62 -> Score=0.88 => Classe 1 (Bom)
# Aresta [-50, 1.8, 22, 0.28] | MLP=1.00, APMR_edge=0.85, MFSR_edge=0.79, IGD=0.62 -> Score=0.88 => Classe 1 (Bom)
# Aresta [-75, 5.2, 65, 0.6] | MLP=0.00, APMR_edge=0.85, MFSR_edge=0.78, IGD=0.62 -> Score=0.38 => Classe 0 (Ruim)
# Aresta [-78, 4.8, 70, 0.65] | MLP=0.00, APMR_edge=0.85, MFSR_edge=0.77, IGD=0.62 -> Score=0.38 => Classe 0 (Ruim)
# Aresta [-72, 5.5, 60, 0.58] | MLP=0.00, APMR_edge=0.85, MFSR_edge=0.76, IGD=0.62 -> Score=0.38 => Classe 0 (Ruim)
# Aresta [-45, 4.5, 15, 0.7] | MLP=0.57, APMR_edge=0.84, MFSR_edge=0.74, IGD=0.62 -> Score=0.66 => Classe 1 (Bom)
# Aresta [-70, 1.9, 45, 0.2] | MLP=0.89, APMR_edge=0.83, MFSR_edge=0.73, IGD=0.62 -> Score=0.81 => Classe 1 (Bom)
# Aresta [-60, 2.9, 30, 0.3] | MLP=0.96, APMR_edge=0.81, MFSR_edge=0.72, IGD=0.62 -> Score=0.84 => Classe 1 (Bom)
# Aresta [-65, 2.2, 18, 0.25] | MLP=0.99, APMR_edge=0.80, MFSR_edge=0.70, IGD=0.62 -> Score=0.85 => Classe 1 (Bom)
# Aresta [-50, 3.5, 35, 0.35] | MLP=0.94, APMR_edge=0.78, MFSR_edge=0.69, IGD=0.62 -> Score=0.82 => Classe 1 (Bom)
# Aresta [-32, 1.1, 3, 0.02] | MLP=1.00, APMR_edge=0.75, MFSR_edge=0.68, IGD=0.62 -> Score=0.85 => Classe 1 (Bom)
# Aresta [-90, 9.8, 98, 0.95] | MLP=0.00, APMR_edge=0.73, MFSR_edge=0.66, IGD=0.62 -> Score=0.34 => Classe 0 (Ruim)
# Aresta [-38, 1.3, 7, 0.08] | MLP=1.00, APMR_edge=0.70, MFSR_edge=0.65, IGD=0.62 -> Score=0.83 => Classe 1 (Bom)
# Aresta [-86, 8.5, 88, 0.85] | MLP=0.00, APMR_edge=0.68, MFSR_edge=0.64, IGD=0.62 -> Score=0.32 => Classe 0 (Ruim)
# Aresta [-42, 1.6, 12, 0.12] | MLP=1.00, APMR_edge=0.65, MFSR_edge=0.62, IGD=0.62 -> Score=0.82 => Classe 1 (Bom)
# Aresta [-33, 7.2, 75, 0.8] | MLP=0.00, APMR_edge=0.62, MFSR_edge=0.61, IGD=0.62 -> Score=0.31 => Classe 0 (Ruim)
# Aresta [-82, 1.2, 8, 0.1] | MLP=0.99, APMR_edge=0.60, MFSR_edge=0.60, IGD=0.62 -> Score=0.80 => Classe 1 (Bom)
# Aresta [-75, 8.1, 5, 0.85] | MLP=0.00, APMR_edge=0.57, MFSR_edge=0.59, IGD=0.62 -> Score=0.30 => Classe 0 (Ruim)
# Aresta [-68, 6.5, 85, 0.05] | MLP=0.01, APMR_edge=0.55, MFSR_edge=0.58, IGD=0.62 -> Score=0.29 => Classe 0 (Ruim)
# Aresta [-89, 2.1, 18, 0.15] | MLP=0.87, APMR_edge=0.52, MFSR_edge=0.58, IGD=0.62 -> Score=0.72 => Classe 1 (Bom)
# Aresta [-45, 9.2, 22, 0.2] | MLP=0.20, APMR_edge=0.50, MFSR_edge=0.57, IGD=0.62 -> Score=0.38 => Classe 0 (Ruim)
# Aresta [-52, 2.3, 95, 0.25] | MLP=0.21, APMR_edge=0.49, MFSR_edge=0.56, IGD=0.62 -> Score=0.38 => Classe 0 (Ruim)
# Aresta [-48, 2.0, 20, 0.88] | MLP=0.69, APMR_edge=0.47, MFSR_edge=0.56, IGD=0.62 -> Score=0.62 => Classe 1 (Bom)
# Aresta [-59, 3.0, 29, 0.29] | MLP=0.97, APMR_edge=0.46, MFSR_edge=0.55, IGD=0.62 -> Score=0.75 => Classe 1 (Bom)
# Aresta [-61, 2.9, 31, 0.31] | MLP=0.94, APMR_edge=0.45, MFSR_edge=0.55, IGD=0.62 -> Score=0.74 => Classe 1 (Bom)
# Aresta [-60.5, 3.05, 30.5, 0.305] | MLP=0.94, APMR_edge=0.45, MFSR_edge=0.55, IGD=0.62 -> Score=0.74 => Classe 1 (Bom)
# Aresta [-59.5, 2.95, 29.5, 0.295] | MLP=0.96, APMR_edge=0.45, MFSR_edge=0.55, IGD=0.62 -> Score=0.75 => Classe 1 (Bom)
# Aresta [-67, 4.2, 45, 0.5] | MLP=0.03, APMR_edge=0.45, MFSR_edge=0.55, IGD=0.62 -> Score=0.28 => Classe 0 (Ruim)
# Aresta [-64, 3.8, 42, 0.48] | MLP=0.11, APMR_edge=0.46, MFSR_edge=0.55, IGD=0.62 -> Score=0.32 => Classe 0 (Ruim)
# Aresta [-69, 4.5, 48, 0.52] | MLP=0.01, APMR_edge=0.47, MFSR_edge=0.56, IGD=0.62 -> Score=0.28 => Classe 0 (Ruim)
# Aresta [-66, 4.0, 40, 0.45] | MLP=0.11, APMR_edge=0.49, MFSR_edge=0.56, IGD=0.62 -> Score=0.33 => Classe 0 (Ruim)
# Aresta [-54, 1.9, 16, 0.28] | MLP=1.00, APMR_edge=0.50, MFSR_edge=0.57, IGD=0.62 -> Score=0.78 => Classe 1 (Bom)
# Aresta [-56, 2.2, 19, 0.26] | MLP=1.00, APMR_edge=0.52, MFSR_edge=0.58, IGD=0.62 -> Score=0.78 => Classe 1 (Bom)
# Aresta [-51, 1.7, 21, 0.24] | MLP=1.00, APMR_edge=0.55, MFSR_edge=0.58, IGD=0.62 -> Score=0.79 => Classe 1 (Bom)
# Aresta [-49, 2.4, 18, 0.27] | MLP=1.00, APMR_edge=0.57, MFSR_edge=0.59, IGD=0.62 -> Score=0.79 => Classe 1 (Bom)
# Aresta [-53, 2.0, 23, 0.29] | MLP=1.00, APMR_edge=0.60, MFSR_edge=0.60, IGD=0.62 -> Score=0.80 => Classe 1 (Bom)
# Aresta [-76, 5.8, 67, 0.63] | MLP=0.00, APMR_edge=0.62, MFSR_edge=0.61, IGD=0.62 -> Score=0.31 => Classe 0 (Ruim)
# Aresta [-74, 5.1, 62, 0.59] | MLP=0.00, APMR_edge=0.65, MFSR_edge=0.62, IGD=0.62 -> Score=0.32 => Classe 0 (Ruim)
# Aresta [-77, 6.2, 72, 0.68] | MLP=0.00, APMR_edge=0.68, MFSR_edge=0.64, IGD=0.62 -> Score=0.32 => Classe 0 (Ruim)
# Aresta [-73, 5.5, 58, 0.56] | MLP=0.00, APMR_edge=0.70, MFSR_edge=0.65, IGD=0.62 -> Score=0.33 => Classe 0 (Ruim)
# Aresta [-79, 5.9, 75, 0.71] | MLP=0.00, APMR_edge=0.73, MFSR_edge=0.66, IGD=0.62 -> Score=0.34 => Classe 0 (Ruim)
# Aresta [-55, 1.8, 35, 0.6] | MLP=0.83, APMR_edge=0.75, MFSR_edge=0.68, IGD=0.62 -> Score=0.76 => Classe 1 (Bom)
# Aresta [-45, 4.2, 25, 0.7] | MLP=0.42, APMR_edge=0.78, MFSR_edge=0.69, IGD=0.62 -> Score=0.56 => Classe 1 (Bom)
# Aresta [-65, 2.5, 18, 0.55] | MLP=0.80, APMR_edge=0.80, MFSR_edge=0.70, IGD=0.62 -> Score=0.76 => Classe 1 (Bom)
# Aresta [-58, 3.8, 28, 0.8] | MLP=0.04, APMR_edge=0.81, MFSR_edge=0.72, IGD=0.62 -> Score=0.38 => Classe 0 (Ruim)
# Aresta [-41, 5.0, 50, 0.5] | MLP=0.17, APMR_edge=0.83, MFSR_edge=0.73, IGD=0.62 -> Score=0.45 => Classe 0 (Ruim)
# Aresta [-80, 2.0, 20, 0.2] | MLP=0.94, APMR_edge=0.84, MFSR_edge=0.74, IGD=0.62 -> Score=0.84 => Classe 1 (Bom)
# Aresta [-60, 6.0, 60, 0.6] | MLP=0.00, APMR_edge=0.85, MFSR_edge=0.76, IGD=0.62 -> Score=0.38 => Classe 0 (Ruim)
# Aresta [-50, 2.5, 25, 0.25] | MLP=1.00, APMR_edge=0.85, MFSR_edge=0.77, IGD=0.62 -> Score=0.88 => Classe 1 (Bom)
# Aresta [-57, 2.8, 28, 0.28] | MLP=0.98, APMR_edge=0.85, MFSR_edge=0.78, IGD=0.62 -> Score=0.87 => Classe 1 (Bom)
# Aresta [-63, 3.2, 32, 0.32] | MLP=0.88, APMR_edge=0.85, MFSR_edge=0.79, IGD=0.62 -> Score=0.82 => Classe 1 (Bom)
# Aresta [-58, 2.9, 31, 0.29] | MLP=0.97, APMR_edge=0.84, MFSR_edge=0.80, IGD=0.62 -> Score=0.86 => Classe 1 (Bom)
# Aresta [-62, 3.1, 29, 0.31] | MLP=0.93, APMR_edge=0.83, MFSR_edge=0.81, IGD=0.62 -> Score=0.85 => Classe 1 (Bom)
# Aresta [-30, 1.0, 1, 0.01] | MLP=1.00, APMR_edge=0.81, MFSR_edge=0.82, IGD=0.62 -> Score=0.88 => Classe 1 (Bom)
# Aresta [-90, 10.0, 100, 1.0] | MLP=0.00, APMR_edge=0.80, MFSR_edge=0.83, IGD=0.62 -> Score=0.38 => Classe 0 (Ruim)
# Aresta [-31, 1.5, 10, 0.05] | MLP=1.00, APMR_edge=0.78, MFSR_edge=0.83, IGD=0.62 -> Score=0.87 => Classe 1 (Bom)
# Aresta [-89, 9.0, 90, 0.9] | MLP=0.00, APMR_edge=0.75, MFSR_edge=0.84, IGD=0.62 -> Score=0.37 => Classe 0 (Ruim)
# Aresta [-44, 7.5, 12, 0.15] | MLP=0.93, APMR_edge=0.73, MFSR_edge=0.84, IGD=0.62 -> Score=0.83 => Classe 1 (Bom)
# Aresta [-83, 1.8, 78, 0.75] | MLP=0.00, APMR_edge=0.70, MFSR_edge=0.85, IGD=0.62 -> Score=0.36 => Classe 0 (Ruim)
# Aresta [-38, 6.8, 8, 0.82] | MLP=0.10, APMR_edge=0.68, MFSR_edge=0.85, IGD=0.62 -> Score=0.40 => Classe 0 (Ruim)
# Aresta [-71, 1.4, 55, 0.18] | MLP=0.84, APMR_edge=0.65, MFSR_edge=0.85, IGD=0.62 -> Score=0.77 => Classe 1 (Bom)

# %%
# ====== Plot comparando ML, Fusão e Kalman ======
plt.figure(figsize=(10,6))
plt.plot(prob_ml, label="ML Puro", alpha=0.7)
plt.plot(fusion_scores, label="Fusão (ML+Radnet)", alpha=0.7)
plt.plot(kalman_scores, label="Kalman (suavizado)", linewidth=2)
plt.xlabel("Amostra (aresta)")
plt.ylabel("Score de Qualidade")
plt.title("Comparação: ML Puro vs Fusão vs Kalman")
plt.legend()
plt.grid(True)
plt.show()
